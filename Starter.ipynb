# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /home/siddesh/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/siddesh/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
df  = pd.read_csv("Data/retail_Case_Study.csv")
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head()
# Out:
#                 Bill_number       Date  Customer_No Transaction_Month  \
# 0  1005|1305|105|1|20120805 2012-05-08   3013241207               Aug
# 1  1005|1305|105|1|20120805 2012-05-08   3013241207               Aug
# 2  1005|1305|105|1|20120805 2012-05-08   3013241207               Aug
# 3  1005|1305|105|1|20120805 2012-05-08   3013241207               Aug
# 4  1005|1305|105|1|20120805 2012-05-08   3013241207               Aug
#
#    Sku_Number  Sales                Item_Description           Deparment  \
# 0   100394188  200.0  AIRWICK FRESHMATIC RF ROSE                    Food
# 1   100500503  199.0  Bathroom set 4Pc Blue           GENERALMERCHANDISE
# 2   100114158  190.0  MCCAINS MOZARELLA CHSSTICKS300                Food
# 3   100114156  190.0  MCCAINS JALAPENO NUGGETS 300                  Food
# 4   100127198  179.0  Stor Cont 4SL Rnd 1.15l YP041.  GENERALMERCHANDISE
#
#   Sub_Deparment
# 0      HOMECARE
# 1      HOMEWARE
# 2        FROZEN
# 3        FROZEN
# 4      HOMEWARE

# %%
df.describe()
# Out:
#         Customer_No    Sku_Number          Sales
# count  2.007380e+05  2.007380e+05  200738.000000
# mean   3.013953e+09  9.249640e+07     127.708875
# std    5.856085e+05  2.669752e+07     695.459883
# min    3.012593e+09  1.000000e+03  -21100.000000
# 25%    3.013251e+09  1.000124e+08      24.000000
# 50%    3.013837e+09  1.001156e+08      50.000000
# 75%    3.014738e+09  1.003816e+08     115.000000
# max    3.014862e+09  1.005840e+08   64000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200738 entries, 0 to 200737
# Data columns (total 9 columns):
# Bill_number          200738 non-null object
# Date                 200738 non-null datetime64[ns]
# Customer_No          200738 non-null int64
# Transaction_Month    200738 non-null object
# Sku_Number           200738 non-null int64
# Sales                200738 non-null float64
# Item_Description     200738 non-null object
# Deparment            200738 non-null object
# Sub_Deparment        200738 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 13.8+ MB

# %%
df1 = df.drop(["Sku_Number"],axis=1)

# %%
(df1["Item_Description"].value_counts())
# Out:
# Discovery Club Primary Enrlmn.    7040
# SLICE 1.2LTR  PET            .    1527
# Hypermart SUGAR PR 5 KG      .     927
# CADBURY OREO BISCCUIT 137.2GM      830
# POTATO                             715
# KISSAN JAMMIX FRT 200G JULY PR     609
# BIKAJI NMKN BHUJIA SEV 1KG         606
# 5 STAR 28G / 30G  SOFT BAR         583
# SUNFEAST DRK FNTSY CHOC104GM       580
# ONION RED.                         577
# UNIBIC CHOCKISS 90GM MAY PROMO     559
# TATA SALT  1 KG PP                 529
# HEALTHY CHOICE POHA 1 KG           504
# TOMATO                       .     499
# BRTNIA LITTLE HEARTS 48GM          471
# CADB DM 38/40G                     458
# PINEAPPLE WHOLE              .     458
# BRITANNIA GOOD DAY 75 GM PROMO     454
# CUCUMBER GREEN               .     454
# PREMIUM BANANA                     450
# FERRERO KINDER JOY 20G             437
# CAPSICUM GREEN               .     405
# ROOH AFZA SHARBAT 700ML            399
# PARLE HIDE & SEEK 93.75/82.5GM     397
# ...

# %%
plt.pie(df1["Item_Description"].value_counts(),labels=df1["Item_Description"].value_counts().index)
plt.axis('equal')
plt.show()
